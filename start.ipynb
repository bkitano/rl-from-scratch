# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

# Parallel environments
vec_env = make_vec_env("LunarLander-v2", n_envs=4)

model = PPO(**{
    "policy": "MlpPolicy", 
    "env": vec_env,
    "n_steps": 1024,
    "batch_size": 64,
    "n_epochs": 4,
    "gamma": .999,
    "gae_lambda":.98,
    "ent_coef":.01,
    "verbose":1
    })
model.learn(total_timesteps=1e6)
model.save("lunar_lander")

# del model # remove to demonstrate saving and loading
# model = PPO.load("lunar_lander")

obs = vec_env.reset()
step = 0
while step < 1000:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = vec_env.step(action)
    # vec_env.render("human")
    step += 1
vec_env.close()
# Out:
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93       |
# |    ep_rew_mean     | -211     |
# | time/              |          |
# |    fps             | 7100     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 4096     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93.5         |
# |    ep_rew_mean          | -195         |
# | time/                   |              |
# |    fps                  | 5385         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0027297675 |
# |    clip_fraction        | 0.00128      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.00232      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.04e+03     |
# |    n_updates            | 4            |
# |    policy_gradient_loss | -0.00307     |
# |    value_loss           | 7.53e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 92.7         |
# |    ep_rew_mean          | -156         |
# | time/                   |              |
# |    fps                  | 5059         |
# |    iterations           | 3            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0029479717 |
# |    clip_fraction        | 0.00244      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.0114      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.05e+03     |
# |    n_updates            | 8            |
# |    policy_gradient_loss | -0.00299     |
# |    value_loss           | 4.54e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.3        |
# |    ep_rew_mean          | -151        |
# | time/                   |             |
# |    fps                  | 4875        |
# |    iterations           | 4           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008377859 |
# |    clip_fraction        | 0.0251      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.000308   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.09e+03    |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.00463    |
# |    value_loss           | 2.68e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.4        |
# |    ep_rew_mean          | -157        |
# | time/                   |             |
# |    fps                  | 4800        |
# |    iterations           | 5           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007406085 |
# |    clip_fraction        | 0.0262      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.0215     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.55e+03    |
# |    n_updates            | 16          |
# |    policy_gradient_loss | -0.00496    |
# |    value_loss           | 3.77e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -147        |
# | time/                   |             |
# |    fps                  | 4739        |
# |    iterations           | 6           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007949808 |
# |    clip_fraction        | 0.0236      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.000605   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1e+03       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00567    |
# |    value_loss           | 2.19e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 104         |
# |    ep_rew_mean          | -144        |
# | time/                   |             |
# |    fps                  | 4632        |
# |    iterations           | 7           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.011354113 |
# |    clip_fraction        | 0.037       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.00238    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.08e+03    |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.00605    |
# |    value_loss           | 2.05e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 104         |
# |    ep_rew_mean          | -144        |
# | time/                   |             |
# |    fps                  | 4590        |
# |    iterations           | 8           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008234967 |
# |    clip_fraction        | 0.0281      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.00582    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02e+03    |
# |    n_updates            | 28          |
# |    policy_gradient_loss | -0.00564    |
# |    value_loss           | 2.6e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 108        |
# |    ep_rew_mean          | -132       |
# | time/                   |            |
# |    fps                  | 4512       |
# |    iterations           | 9          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.00889837 |
# |    clip_fraction        | 0.0259     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | -0.00231   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 496        |
# |    n_updates            | 32         |
# |    policy_gradient_loss | -0.00508   |
# |    value_loss           | 1.47e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 106         |
# |    ep_rew_mean          | -121        |
# | time/                   |             |
# |    fps                  | 4233        |
# |    iterations           | 10          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008363092 |
# |    clip_fraction        | 0.048       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -0.00134    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 409         |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.00339    |
# |    value_loss           | 1.02e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 109          |
# |    ep_rew_mean          | -118         |
# | time/                   |              |
# |    fps                  | 4224         |
# |    iterations           | 11           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0061854245 |
# |    clip_fraction        | 0.0764       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -0.00656     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 403          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00942     |
# |    value_loss           | 1.23e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 113          |
# |    ep_rew_mean          | -111         |
# | time/                   |              |
# |    fps                  | 4183         |
# |    iterations           | 12           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0060497336 |
# |    clip_fraction        | 0.0297       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | -0.002       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 524          |
# |    n_updates            | 44           |
# |    policy_gradient_loss | -0.00618     |
# |    value_loss           | 805          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 113         |
# |    ep_rew_mean          | -81.6       |
# | time/                   |             |
# |    fps                  | 4189        |
# |    iterations           | 13          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.006184778 |
# |    clip_fraction        | 0.0746      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | -0.00079    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 326         |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.00312    |
# |    value_loss           | 758         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 113         |
# |    ep_rew_mean          | -70.2       |
# | time/                   |             |
# |    fps                  | 4123        |
# |    iterations           | 14          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.013134625 |
# |    clip_fraction        | 0.0765      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | -2.36e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 167         |
# |    n_updates            | 52          |
# |    policy_gradient_loss | -0.00497    |
# |    value_loss           | 398         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 125         |
# |    ep_rew_mean          | -55.5       |
# | time/                   |             |
# |    fps                  | 3958        |
# |    iterations           | 15          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.011353107 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.000313    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 236         |
# |    n_updates            | 56          |
# |    policy_gradient_loss | -0.00605    |
# |    value_loss           | 519         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 130        |
# |    ep_rew_mean          | -52        |
# | time/                   |            |
# |    fps                  | 3925       |
# |    iterations           | 16         |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.01007402 |
# |    clip_fraction        | 0.0566     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.22      |
# |    explained_variance   | -0.00206   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 179        |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00839   |
# |    value_loss           | 369        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 146          |
# |    ep_rew_mean          | -46.6        |
# | time/                   |              |
# |    fps                  | 3740         |
# |    iterations           | 17           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0043047844 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.00127      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 249          |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.00264     |
# |    value_loss           | 449          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 169          |
# |    ep_rew_mean          | -40.5        |
# | time/                   |              |
# |    fps                  | 3558         |
# |    iterations           | 18           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0062820213 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.0515       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 260          |
# |    n_updates            | 68           |
# |    policy_gradient_loss | -0.0036      |
# |    value_loss           | 396          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -34.5        |
# | time/                   |              |
# |    fps                  | 3248         |
# |    iterations           | 19           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0030506388 |
# |    clip_fraction        | 0.00946      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.0601       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 147          |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.00144     |
# |    value_loss           | 484          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 206         |
# |    ep_rew_mean          | -32.4       |
# | time/                   |             |
# |    fps                  | 3187        |
# |    iterations           | 20          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.005523484 |
# |    clip_fraction        | 0.0413      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.126       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 138         |
# |    n_updates            | 76          |
# |    policy_gradient_loss | -0.00459    |
# |    value_loss           | 301         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 226          |
# |    ep_rew_mean          | -30.7        |
# | time/                   |              |
# |    fps                  | 2995         |
# |    iterations           | 21           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0020776403 |
# |    clip_fraction        | 0.00482      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.114        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 174          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00145     |
# |    value_loss           | 492          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 254        |
# |    ep_rew_mean          | -25.2      |
# | time/                   |            |
# |    fps                  | 2929       |
# |    iterations           | 22         |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.00470593 |
# |    clip_fraction        | 0.00671    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.26      |
# |    explained_variance   | 0.138      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 192        |
# |    n_updates            | 84         |
# |    policy_gradient_loss | -0.00302   |
# |    value_loss           | 522        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 255         |
# |    ep_rew_mean          | -26.8       |
# | time/                   |             |
# |    fps                  | 2884        |
# |    iterations           | 23          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.003057716 |
# |    clip_fraction        | 0.0109      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.185       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 246         |
# |    n_updates            | 88          |
# |    policy_gradient_loss | -0.0019     |
# |    value_loss           | 472         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 263          |
# |    ep_rew_mean          | -23.5        |
# | time/                   |              |
# |    fps                  | 2814         |
# |    iterations           | 24           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0043461947 |
# |    clip_fraction        | 0.0113       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.208        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 266          |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.00269     |
# |    value_loss           | 477          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 292          |
# |    ep_rew_mean          | -17          |
# | time/                   |              |
# |    fps                  | 2691         |
# |    iterations           | 25           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0030711375 |
# |    clip_fraction        | 0.0131       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.255        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 150          |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.00204     |
# |    value_loss           | 445          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 272         |
# |    ep_rew_mean          | -14.8       |
# | time/                   |             |
# |    fps                  | 2660        |
# |    iterations           | 26          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.006297446 |
# |    clip_fraction        | 0.0439      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.429       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 90          |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00322    |
# |    value_loss           | 291         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 307        |
# |    ep_rew_mean          | -8.45      |
# | time/                   |            |
# |    fps                  | 2542       |
# |    iterations           | 27         |
# |    time_elapsed         | 43         |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.01009359 |
# |    clip_fraction        | 0.0547     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.18      |
# |    explained_variance   | 0.503      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 189        |
# |    n_updates            | 104        |
# |    policy_gradient_loss | -0.00504   |
# |    value_loss           | 335        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 302          |
# |    ep_rew_mean          | -6.79        |
# | time/                   |              |
# |    fps                  | 2462         |
# |    iterations           | 28           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0057249065 |
# |    clip_fraction        | 0.0288       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.746        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53.7         |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -0.00225     |
# |    value_loss           | 134          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 317          |
# |    ep_rew_mean          | 0.278        |
# | time/                   |              |
# |    fps                  | 2406         |
# |    iterations           | 29           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0038947058 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.555        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 266          |
# |    n_updates            | 112          |
# |    policy_gradient_loss | -0.00292     |
# |    value_loss           | 338          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 342         |
# |    ep_rew_mean          | 2.67        |
# | time/                   |             |
# |    fps                  | 2287        |
# |    iterations           | 30          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.005884251 |
# |    clip_fraction        | 0.0491      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.753       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 105         |
# |    n_updates            | 116         |
# |    policy_gradient_loss | -0.00287    |
# |    value_loss           | 177         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 351          |
# |    ep_rew_mean          | 5.45         |
# | time/                   |              |
# |    fps                  | 2260         |
# |    iterations           | 31           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 126976       |
# | train/                  |              |
# |    approx_kl            | 0.0069315764 |
# |    clip_fraction        | 0.0592       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.719        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.9         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0051      |
# |    value_loss           | 135          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 384         |
# |    ep_rew_mean          | 11.1        |
# | time/                   |             |
# |    fps                  | 2193        |
# |    iterations           | 32          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.004970937 |
# |    clip_fraction        | 0.0147      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.712       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 70.5        |
# |    n_updates            | 124         |
# |    policy_gradient_loss | -0.00216    |
# |    value_loss           | 233         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 414         |
# |    ep_rew_mean          | 16.9        |
# | time/                   |             |
# |    fps                  | 2123        |
# |    iterations           | 33          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 135168      |
# | train/                  |             |
# |    approx_kl            | 0.003371608 |
# |    clip_fraction        | 0.0144      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.798       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 92.7        |
# |    n_updates            | 128         |
# |    policy_gradient_loss | -0.00154    |
# |    value_loss           | 172         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 440          |
# |    ep_rew_mean          | 24.2         |
# | time/                   |              |
# |    fps                  | 2082         |
# |    iterations           | 34           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 139264       |
# | train/                  |              |
# |    approx_kl            | 0.0050735585 |
# |    clip_fraction        | 0.0203       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.638        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 152          |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -0.00242     |
# |    value_loss           | 266          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 450          |
# |    ep_rew_mean          | 25.4         |
# | time/                   |              |
# |    fps                  | 2059         |
# |    iterations           | 35           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 143360       |
# | train/                  |              |
# |    approx_kl            | 0.0044938438 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.802        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 81.2         |
# |    n_updates            | 136          |
# |    policy_gradient_loss | -0.00274     |
# |    value_loss           | 151          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 464          |
# |    ep_rew_mean          | 26.9         |
# | time/                   |              |
# |    fps                  | 2028         |
# |    iterations           | 36           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0067004645 |
# |    clip_fraction        | 0.0428       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.685        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 200          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00593     |
# |    value_loss           | 289          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 477         |
# |    ep_rew_mean          | 28.3        |
# | time/                   |             |
# |    fps                  | 2003        |
# |    iterations           | 37          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 151552      |
# | train/                  |             |
# |    approx_kl            | 0.007905638 |
# |    clip_fraction        | 0.0653      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 114         |
# |    n_updates            | 144         |
# |    policy_gradient_loss | -0.0051     |
# |    value_loss           | 196         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 491          |
# |    ep_rew_mean          | 28.4         |
# | time/                   |              |
# |    fps                  | 1969         |
# |    iterations           | 38           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 155648       |
# | train/                  |              |
# |    approx_kl            | 0.0047260216 |
# |    clip_fraction        | 0.0277       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.78         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 67.4         |
# |    n_updates            | 148          |
# |    policy_gradient_loss | -0.000864    |
# |    value_loss           | 180          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 513         |
# |    ep_rew_mean          | 32          |
# | time/                   |             |
# |    fps                  | 1961        |
# |    iterations           | 39          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 159744      |
# | train/                  |             |
# |    approx_kl            | 0.005592613 |
# |    clip_fraction        | 0.0372      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.806       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.3        |
# |    n_updates            | 152         |
# |    policy_gradient_loss | -0.00208    |
# |    value_loss           | 127         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 521          |
# |    ep_rew_mean          | 36.4         |
# | time/                   |              |
# |    fps                  | 1957         |
# |    iterations           | 40           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0032554327 |
# |    clip_fraction        | 0.0134       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.793        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 113          |
# |    n_updates            | 156          |
# |    policy_gradient_loss | -0.00218     |
# |    value_loss           | 210          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 541          |
# |    ep_rew_mean          | 39.7         |
# | time/                   |              |
# |    fps                  | 1950         |
# |    iterations           | 41           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0037196204 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.828        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 74.7         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0032      |
# |    value_loss           | 164          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 544         |
# |    ep_rew_mean          | 39.4        |
# | time/                   |             |
# |    fps                  | 1923        |
# |    iterations           | 42          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.005158413 |
# |    clip_fraction        | 0.0344      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.994      |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69.4        |
# |    n_updates            | 164         |
# |    policy_gradient_loss | -0.00257    |
# |    value_loss           | 222         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 577          |
# |    ep_rew_mean          | 43.4         |
# | time/                   |              |
# |    fps                  | 1901         |
# |    iterations           | 43           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0050640223 |
# |    clip_fraction        | 0.0463       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.988       |
# |    explained_variance   | 0.8          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 112          |
# |    n_updates            | 168          |
# |    policy_gradient_loss | -0.00783     |
# |    value_loss           | 178          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 587          |
# |    ep_rew_mean          | 46.8         |
# | time/                   |              |
# |    fps                  | 1883         |
# |    iterations           | 44           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0059291637 |
# |    clip_fraction        | 0.0517       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.999       |
# |    explained_variance   | 0.896        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.9         |
# |    n_updates            | 172          |
# |    policy_gradient_loss | -0.00218     |
# |    value_loss           | 55.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 602          |
# |    ep_rew_mean          | 50           |
# | time/                   |              |
# |    fps                  | 1855         |
# |    iterations           | 45           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0065100505 |
# |    clip_fraction        | 0.0775       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.99        |
# |    explained_variance   | 0.901        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.8         |
# |    n_updates            | 176          |
# |    policy_gradient_loss | -0.00313     |
# |    value_loss           | 67.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 635          |
# |    ep_rew_mean          | 53.5         |
# | time/                   |              |
# |    fps                  | 1819         |
# |    iterations           | 46           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0051853023 |
# |    clip_fraction        | 0.0286       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.986       |
# |    explained_variance   | 0.901        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.9         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0035      |
# |    value_loss           | 56.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 653         |
# |    ep_rew_mean          | 54.2        |
# | time/                   |             |
# |    fps                  | 1794        |
# |    iterations           | 47          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.004405379 |
# |    clip_fraction        | 0.0411      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.8        |
# |    n_updates            | 184         |
# |    policy_gradient_loss | -0.00302    |
# |    value_loss           | 71.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 661          |
# |    ep_rew_mean          | 56.3         |
# | time/                   |              |
# |    fps                  | 1780         |
# |    iterations           | 48           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0081849815 |
# |    clip_fraction        | 0.0656       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.948       |
# |    explained_variance   | 0.863        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 78.8         |
# |    n_updates            | 188          |
# |    policy_gradient_loss | -0.00297     |
# |    value_loss           | 84.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 666          |
# |    ep_rew_mean          | 56.1         |
# | time/                   |              |
# |    fps                  | 1763         |
# |    iterations           | 49           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0050622076 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.971       |
# |    explained_variance   | 0.957        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.54         |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.000644    |
# |    value_loss           | 27.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 654         |
# |    ep_rew_mean          | 53.8        |
# | time/                   |             |
# |    fps                  | 1749        |
# |    iterations           | 50          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.003179269 |
# |    clip_fraction        | 0.0168      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.985      |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.2        |
# |    n_updates            | 196         |
# |    policy_gradient_loss | -0.00231    |
# |    value_loss           | 118         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 684         |
# |    ep_rew_mean          | 58.7        |
# | time/                   |             |
# |    fps                  | 1719        |
# |    iterations           | 51          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 208896      |
# | train/                  |             |
# |    approx_kl            | 0.004069597 |
# |    clip_fraction        | 0.0203      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.975      |
# |    explained_variance   | 0.806       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 87.1        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00302    |
# |    value_loss           | 168         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | 66.1         |
# | time/                   |              |
# |    fps                  | 1698         |
# |    iterations           | 52           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0038172016 |
# |    clip_fraction        | 0.0272       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.995       |
# |    explained_variance   | 0.925        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.1         |
# |    n_updates            | 204          |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 44.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 727          |
# |    ep_rew_mean          | 68.3         |
# | time/                   |              |
# |    fps                  | 1678         |
# |    iterations           | 53           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 217088       |
# | train/                  |              |
# |    approx_kl            | 0.0045884335 |
# |    clip_fraction        | 0.0493       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.952        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.92         |
# |    n_updates            | 208          |
# |    policy_gradient_loss | 0.000629     |
# |    value_loss           | 30           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 749          |
# |    ep_rew_mean          | 72.1         |
# | time/                   |              |
# |    fps                  | 1658         |
# |    iterations           | 54           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 221184       |
# | train/                  |              |
# |    approx_kl            | 0.0040588095 |
# |    clip_fraction        | 0.0217       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.967       |
# |    explained_variance   | 0.963        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18           |
# |    n_updates            | 212          |
# |    policy_gradient_loss | -0.00084     |
# |    value_loss           | 20.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 771         |
# |    ep_rew_mean          | 74.6        |
# | time/                   |             |
# |    fps                  | 1638        |
# |    iterations           | 55          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 225280      |
# ...
# |    ep_len_mean          | 306          |
# |    ep_rew_mean          | 236          |
# | time/                   |              |
# |    fps                  | 1599         |
# |    iterations           | 228          |
# |    time_elapsed         | 583          |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0014369632 |
# |    clip_fraction        | 0.0107       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.77        |
# |    explained_variance   | 0.715        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 284          |
# |    n_updates            | 908          |
# |    policy_gradient_loss | -0.000897    |
# |    value_loss           | 441          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 305         |
# |    ep_rew_mean          | 238         |
# | time/                   |             |
# |    fps                  | 1602        |
# |    iterations           | 229         |
# |    time_elapsed         | 585         |
# |    total_timesteps      | 937984      |
# | train/                  |             |
# |    approx_kl            | 0.005975823 |
# |    clip_fraction        | 0.0419      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.705      |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.45        |
# |    n_updates            | 912         |
# |    policy_gradient_loss | -0.000911   |
# |    value_loss           | 25.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 303         |
# |    ep_rew_mean          | 248         |
# | time/                   |             |
# |    fps                  | 1604        |
# |    iterations           | 230         |
# |    time_elapsed         | 587         |
# |    total_timesteps      | 942080      |
# | train/                  |             |
# |    approx_kl            | 0.004810157 |
# |    clip_fraction        | 0.0464      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.706      |
# |    explained_variance   | 0.746       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 90.5        |
# |    n_updates            | 916         |
# |    policy_gradient_loss | -0.00234    |
# |    value_loss           | 455         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 305          |
# |    ep_rew_mean          | 253          |
# | time/                   |              |
# |    fps                  | 1606         |
# |    iterations           | 231          |
# |    time_elapsed         | 588          |
# |    total_timesteps      | 946176       |
# | train/                  |              |
# |    approx_kl            | 0.0056659356 |
# |    clip_fraction        | 0.0699       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.727       |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.56         |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.000977    |
# |    value_loss           | 10.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 301          |
# |    ep_rew_mean          | 246          |
# | time/                   |              |
# |    fps                  | 1609         |
# |    iterations           | 232          |
# |    time_elapsed         | 590          |
# |    total_timesteps      | 950272       |
# | train/                  |              |
# |    approx_kl            | 0.0042531146 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.782       |
# |    explained_variance   | 0.729        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 166          |
# |    n_updates            | 924          |
# |    policy_gradient_loss | 0.000319     |
# |    value_loss           | 467          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 298          |
# |    ep_rew_mean          | 242          |
# | time/                   |              |
# |    fps                  | 1611         |
# |    iterations           | 233          |
# |    time_elapsed         | 592          |
# |    total_timesteps      | 954368       |
# | train/                  |              |
# |    approx_kl            | 0.0031432442 |
# |    clip_fraction        | 0.00775      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.745       |
# |    explained_variance   | 0.724        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 248          |
# |    n_updates            | 928          |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 667          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 241         |
# | time/                   |             |
# |    fps                  | 1613        |
# |    iterations           | 234         |
# |    time_elapsed         | 593         |
# |    total_timesteps      | 958464      |
# | train/                  |             |
# |    approx_kl            | 0.005256806 |
# |    clip_fraction        | 0.0202      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.704      |
# |    explained_variance   | 0.766       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 248         |
# |    n_updates            | 932         |
# |    policy_gradient_loss | -0.00288    |
# |    value_loss           | 530         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 297         |
# |    ep_rew_mean          | 240         |
# | time/                   |             |
# |    fps                  | 1616        |
# |    iterations           | 235         |
# |    time_elapsed         | 595         |
# |    total_timesteps      | 962560      |
# | train/                  |             |
# |    approx_kl            | 0.005684931 |
# |    clip_fraction        | 0.0389      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.675      |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.8        |
# |    n_updates            | 936         |
# |    policy_gradient_loss | -0.0019     |
# |    value_loss           | 82.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 296          |
# |    ep_rew_mean          | 238          |
# | time/                   |              |
# |    fps                  | 1618         |
# |    iterations           | 236          |
# |    time_elapsed         | 597          |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0019114433 |
# |    clip_fraction        | 0.00171      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.715       |
# |    explained_variance   | 0.729        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 76.6         |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.000945    |
# |    value_loss           | 520          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 294         |
# |    ep_rew_mean          | 234         |
# | time/                   |             |
# |    fps                  | 1621        |
# |    iterations           | 237         |
# |    time_elapsed         | 598         |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.004893464 |
# |    clip_fraction        | 0.0209      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.738      |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.3        |
# |    n_updates            | 944         |
# |    policy_gradient_loss | -0.00143    |
# |    value_loss           | 281         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 293         |
# |    ep_rew_mean          | 238         |
# | time/                   |             |
# |    fps                  | 1623        |
# |    iterations           | 238         |
# |    time_elapsed         | 600         |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.001917464 |
# |    clip_fraction        | 0.00537     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.717      |
# |    explained_variance   | 0.674       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 238         |
# |    n_updates            | 948         |
# |    policy_gradient_loss | -0.00262    |
# |    value_loss           | 727         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 289          |
# |    ep_rew_mean          | 239          |
# | time/                   |              |
# |    fps                  | 1626         |
# |    iterations           | 239          |
# |    time_elapsed         | 602          |
# |    total_timesteps      | 978944       |
# | train/                  |              |
# |    approx_kl            | 0.0056220535 |
# |    clip_fraction        | 0.0488       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.675       |
# |    explained_variance   | 0.918        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.95         |
# |    n_updates            | 952          |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 31.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 291          |
# |    ep_rew_mean          | 249          |
# | time/                   |              |
# |    fps                  | 1627         |
# |    iterations           | 240          |
# |    time_elapsed         | 604          |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0055296337 |
# |    clip_fraction        | 0.0531       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.709       |
# |    explained_variance   | 0.81         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.4         |
# |    n_updates            | 956          |
# |    policy_gradient_loss | -0.00181     |
# |    value_loss           | 247          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 288          |
# |    ep_rew_mean          | 249          |
# | time/                   |              |
# |    fps                  | 1629         |
# |    iterations           | 241          |
# |    time_elapsed         | 605          |
# |    total_timesteps      | 987136       |
# | train/                  |              |
# |    approx_kl            | 0.0045251665 |
# |    clip_fraction        | 0.0527       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.675       |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.57         |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.00116     |
# |    value_loss           | 16.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 291          |
# |    ep_rew_mean          | 253          |
# | time/                   |              |
# |    fps                  | 1629         |
# |    iterations           | 242          |
# |    time_elapsed         | 608          |
# |    total_timesteps      | 991232       |
# | train/                  |              |
# |    approx_kl            | 0.0050957855 |
# |    clip_fraction        | 0.0639       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.741       |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.24         |
# |    n_updates            | 964          |
# |    policy_gradient_loss | -0.000903    |
# |    value_loss           | 10.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 292          |
# |    ep_rew_mean          | 257          |
# | time/                   |              |
# |    fps                  | 1631         |
# |    iterations           | 243          |
# |    time_elapsed         | 610          |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0051157796 |
# |    clip_fraction        | 0.051        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.748       |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.14         |
# |    n_updates            | 968          |
# |    policy_gradient_loss | -0.00208     |
# |    value_loss           | 10.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 296          |
# |    ep_rew_mean          | 264          |
# | time/                   |              |
# |    fps                  | 1633         |
# |    iterations           | 244          |
# |    time_elapsed         | 611          |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0048549213 |
# |    clip_fraction        | 0.0563       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.703       |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.14         |
# |    n_updates            | 972          |
# |    policy_gradient_loss | -0.00114     |
# |    value_loss           | 7.7          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 298        |
# |    ep_rew_mean          | 267        |
# | time/                   |            |
# |    fps                  | 1636       |
# |    iterations           | 245        |
# |    time_elapsed         | 613        |
# |    total_timesteps      | 1003520    |
# | train/                  |            |
# |    approx_kl            | 0.00525574 |
# |    clip_fraction        | 0.0491     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.714     |
# |    explained_variance   | 0.992      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.06       |
# |    n_updates            | 976        |
# |    policy_gradient_loss | -0.00132   |
# |    value_loss           | 7.57       |
# ----------------------------------------

# %%
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
import gymnasium as gym

eval_env = Monitor(gym.make("LunarLander-v2"))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
mean_reward
# Out:
# 245.0336957
